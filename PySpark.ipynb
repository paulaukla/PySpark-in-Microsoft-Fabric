# %% [markdown]
# ## Create a *df* Spark DataFrame containing CSV data from *"Files/MtoMActual.csv"* and display the result.

# %%
df = spark.read.format("csv").option("header","true").load("Files/MtoMActual.csv")
display(df)
# Out:
# StatementMeta(, 8e3da64d-1864-421f-9d67-ee302babedb9, 3, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 87107969-876f-4eed-b8b6-9ca5b11ae17c)

# %% [markdown]
# ## Save the *df* Spark DataFrame as *MtoMActual* delta table.

# %%
df.write.mode("overwrite").format("delta").saveAsTable("MtoMActual")
# Out:
# StatementMeta(, 8e3da64d-1864-421f-9d67-ee302babedb9, 6, Finished, Available, Finished, False)

# %% [markdown]
# ## Show the *MtoMActual* delta table result in 4 different ways.

# %%
df = spark.read.table("MtoMActual")
display(df)
# Out:
# StatementMeta(, 8e3da64d-1864-421f-9d67-ee302babedb9, 7, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 50993c03-b9a7-4091-8ff0-02f0efde23f0)

# %%
df2 = spark.read.format("delta").load("Tables/dbo/MtoMActual")
display(df2)
# Out:
# StatementMeta(, 8e3da64d-1864-421f-9d67-ee302babedb9, 11, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 22295d72-efc3-49d3-b6cd-5cc641953645)

# %%
df3 = spark.sql("SELECT * FROM MtoMActual")
display(df3)
# Out:
# StatementMeta(, 8e3da64d-1864-421f-9d67-ee302babedb9, 13, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 87fddd0b-df24-4189-aff7-a34558c9531f)

# %%
# %%sql
# SELECT *
# FROM MtoMActual
# Out:
# StatementMeta(, 8e3da64d-1864-421f-9d67-ee302babedb9, 12, Finished, Available, Finished, False)
# <Spark SQL result set with 6 rows and 3 fields>
